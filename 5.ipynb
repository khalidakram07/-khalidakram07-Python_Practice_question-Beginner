# %% [markdown]
# <a href="https://colab.research.google.com/github/khalidakram07/-khalidakram07-Python_Practice_question-Beginner/blob/main/5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5-8 Hello admin
names=['Khalid','admin','Mj','Rooney','Jordan']
for i in names:
  if i=='admin':
    print("hello admin,would you like to see the statuts report")
  else:
    print("Hello",i,", thankyou for logging in again" )
# Out:
# Hello Khalid ,thankyou for logging in again
# hello admin,would you like to see the statuts report
# Hello Mj ,thankyou for logging in again
# Hello Rooney ,thankyou for logging in again
# Hello Jordan ,thankyou for logging in again

# %%
#5-9 no users

names=['Khalid','admin','Mj','Rooney','Jordan']
for i in names:
  if i=='admin':
    print("hello admin,would you like to see the statuts report")
  else:
    print("Hello",i,", thankyou for logging in again" )  

print("\nDeleting users from the list to print the desired result\n")


  
while len(names)!=0:
  print("Current list has",names)
  print("Removing first element from array")
  del names[0]
  print(names,"\n")
  if not names:
    sum=[]
    print("RESULT: We need to find some users")
  else:
    print("List contains ",len(names),"names")
# Out:
# Hello Khalid , thankyou for logging in again
# hello admin,would you like to see the statuts report
# Hello Mj , thankyou for logging in again
# Hello Rooney , thankyou for logging in again
# Hello Jordan , thankyou for logging in again
#
# Deleting users from the list to print the desired result
#
# Current list has ['Khalid', 'admin', 'Mj', 'Rooney', 'Jordan']
# Removing first element from array
# ['admin', 'Mj', 'Rooney', 'Jordan']
#
# List contains  4 names
# Current list has ['admin', 'Mj', 'Rooney', 'Jordan']
# Removing first element from array
# ['Mj', 'Rooney', 'Jordan']
#
# List contains  3 names
# Current list has ['Mj', 'Rooney', 'Jordan']
# Removing first element from array
# ['Rooney', 'Jordan']
#
# List contains  2 names
# Current list has ['Rooney', 'Jordan']
# Removing first element from array
# ['Jordan']
#
# List contains  1 names
# Current list has ['Jordan']
# Removing first element from array
# []
#
# RESULT: We need to find some users

# %% [markdown]
# ![5-10.PNG](data:image/png;base64,...)

# %%
current_users=['Khalid','akram','admin','Mj','Rooney','Jordan']

new_users=['Khalid','akram','Rihanna','Lady Gaga','Selena','T-Pain']

#looping between the list to check if elements are present in the list1 compared to list2

if len(main_list)!=0:
  main_list=[item for item in new_users if item  in current_users]
  print("Name already exist, Please enter name other than:",main_list)
else:
  print("User name is available")
# Out:
# Name already exist, Please enter name other than: ['Khalid', 'akram']

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
for number in range(1,10):
    ordinals = {
        1: 'st',
        2: 'nd',
        3: 'rd'
    }
    if number < 4:
        ordinal = ordinals[number]
    else:
        ordinal = 'th'
    print(f'{number}{ordinal}')
# Out:
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
